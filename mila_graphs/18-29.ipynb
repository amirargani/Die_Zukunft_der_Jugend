# %%
# Bibliotheke
import pandas as pd

# %%
# Dateien einlesen
selbsteinschaetzung = pd.read_csv("Selbsteinschätzung nach Altersgruppen.csv")
angst = pd.read_csv("Angstsymptome nach Altersgruppen.csv")
depression = pd.read_csv("Depressionssymptome nach Altersgruppen.csv")

# %%
display(selbsteinschaetzung.head())

# %%
display(angst.head())

# %%
display(selbsteinschaetzung.head())

# %%
# DataFrames mit einer zusätzlichen Spalte versehen, um die Datenquelle zu identifizieren
selbsteinschaetzung['Quelle'] = 'Selbsteinschätzung'
angst['Quelle'] = 'Angst'
depression['Quelle'] = 'Depression'

# %%
# DataFrames zusammenführen
alle_daten = pd.concat([selbsteinschaetzung, angst, depression], ignore_index=True)

# %%
# Filtern nach Altersgruppe 18-29
altersgruppe_18_29 = alle_daten[alle_daten['Altersgruppe'] == '18-29']

# %%
display(altersgruppe_18_29.head())

# %%
# Speichern als CSV
altersgruppe_18_29.to_csv("psychische_gesundheit_18_29.csv", index=False)
